# %%
#import libraries
import pandas as pd
import numpy as np

# %%
#reading the excel file
df1=pd.read_csv("DEC_Dataset.csv")
df1
# Out:
#          Date  Region Area (km square) Population (Consensus 2017)  \
# 0    11-03-20     ICT              906                   2,001,579
# 1    11-03-20  Punjab          205,345                 119,017,465
# 2    11-03-20   Sindh          140,914                  47,893,244
# 3    11-03-20      KP           74,521                  39,523,371
# 4    11-03-20    KPTD           27,220                   4,996,556
# ..        ...     ...              ...                         ...
# 329  25-04-20      GB           72,496                   1,900,000
# 330  25-04-20     ICT              906                   2,001,579
# 331  25-04-20      KP           74,521                  39,523,371
# 332  25-04-20  Punjab          205,345                 119,017,465
# 333  25-04-20   Sindh          140,914                  47,893,244
#
#      COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)  \
# 0                                                    1
# ...

# %%
df1.shape
# Out:
# (334, 24)

# %%
#total count of each region
df1.Region = df1.Region.apply(lambda x: x.strip())
Region_stats = df1['Region'].value_counts(ascending=False)
Region_stats
# Out:
# KP             46
# GB             46
# ICT            46
# Punjab         46
# AJK            46
# Balochistan    46
# Sindh          46
# KPTD           12
# Name: Region, dtype: int64

# %%
#dropping the unwanted columns
df2=df1.drop(['Home Quarantine','Total Admitted','Admitted Critical','Home Quarantine.1'],axis='columns')
df2.head()
# Out:
#        Date  Region Area (km square) Population (Consensus 2017)  \
# 0  11-03-20     ICT              906                   2,001,579
# 1  11-03-20  Punjab          205,345                 119,017,465
# 2  11-03-20   Sindh          140,914                  47,893,244
# 3  11-03-20      KP           74,521                  39,523,371
# 4  11-03-20    KPTD           27,220                   4,996,556
#
#    COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)  \
# 0                                                  1
# 1                                                  1
# 2                                                  1
# 3                                                  1
# 4                                                  1
#
#    Cumulative Cases  Cumulative  tests performed  Cumulative  Test positive  \
# 0                48                           80                          2
# ...

# %%
df2.shape
# Out:
# (334, 20)

# %%
#count of empty columns and rows
df2.isnull().sum()
# Out:
# Date                                                                                                0
# Region                                                                                              0
# Area (km square)                                                                                    0
# Population (Consensus 2017)                                                                         0
# COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)      0
# Cumulative Cases                                                                                    0
# Cumulative  tests performed                                                                         0
# Cumulative  Test positive                                                                           0
# Discharged                                                                                          0
# ...

# %%
#dropping the empty 
df3=df2.dropna()
df3.isnull().sum()
# Out:
# Date                                                                                              0
# Region                                                                                            0
# Area (km square)                                                                                  0
# Population (Consensus 2017)                                                                       0
# COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)    0
# Cumulative Cases                                                                                  0
# Cumulative  tests performed                                                                       0
# Cumulative  Test positive                                                                         0
# Discharged                                                                                        0
# ...

# %%
df3.shape
# Out:
# (154, 20)

# %%
df3
# Out:
#          Date       Region Area (km square) Population (Consensus 2017)  \
# 180  04-04-20          AJK           13,297                   4,045,000
# 181  04-04-20  Balochistan          347,190                  12,344,739
# 182  04-04-20           GB           72,496                   1,900,000
# 183  04-04-20          ICT              906                   2,001,579
# 184  04-04-20           KP           74,521                  39,523,371
# ..        ...          ...              ...                         ...
# 329  25-04-20           GB           72,496                   1,900,000
# 330  25-04-20          ICT              906                   2,001,579
# 331  25-04-20           KP           74,521                  39,523,371
# 332  25-04-20       Punjab          205,345                 119,017,465
# 333  25-04-20        Sindh          140,914                  47,893,244
#
#      COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)  \
# ...

# %%
#total count of each region 
df3.Region = df3.Region.apply(lambda x: x.strip())
Region_stats = df3['Region'].value_counts(ascending=False)
Region_stats
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# Balochistan    22
# KP             22
# Sindh          22
# Punjab         22
# GB             22
# ICT            22
# AJK            22
# Name: Region, dtype: int64

# %%
#filtering the data region wise 
g=df3.groupby('Region')
g

# %%
for Region, Region_df3 in g:
    print(Region)
    print(Region_df3)
# Out:
# AJK
#          Date Region Area (km square) Population (Consensus 2017)  \
# 180  04-04-20    AJK           13,297                   4,045,000
# 187  05-04-20    AJK           13,297                   4,045,000
# 194  06-04-20    AJK           13,297                   4,045,000
# 201  07-04-20    AJK           13,297                   4,045,000
# 208  08-04-20    AJK           13,297                   4,045,000
# 215  09-04-20    AJK           13,297                   4,045,000
# 222  10-04-20    AJK           13,297                   4,045,000
# 229  11-04-20    AJK           13,297                   4,045,000
# 236  12-04-20    AJK           13,297                   4,045,000
# 243  13-04-20    AJK           13,297                   4,045,000
# 250  14-04-20    AJK           13,297                   4,045,000
# 257  15-04-20    AJK           13,297                   4,045,000
# 264  16-04-20    AJK           13,297                   4,045,000
# ...

# %%
#data of ICT
regional_data_ICT=df3.Region=='ICT'
df4_ICT=df3[regional_data_ICT].copy()
df4_ICT
# Out:
#          Date Region Area (km square) Population (Consensus 2017)  \
# 183  04-04-20    ICT              906                   2,001,579
# 190  05-04-20    ICT              906                   2,001,579
# 197  06-04-20    ICT              906                   2,001,579
# 204  07-04-20    ICT              906                   2,001,579
# 211  08-04-20    ICT              906                   2,001,579
# 218  09-04-20    ICT              906                   2,001,579
# 225  10-04-20    ICT              906                   2,001,579
# 232  11-04-20    ICT              906                   2,001,579
# 239  12-04-20    ICT              906                   2,001,579
# 246  13-04-20    ICT              906                   2,001,579
# 253  14-04-20    ICT              906                   2,001,579
# 260  15-04-20    ICT              906                   2,001,579
# 267  16-04-20    ICT              906                   2,001,579
# ...

# %%
#data of AJK
regional_data_AJK=df3.Region=='AJK'
df4_AJK=df3[regional_data_AJK].copy()
df4_AJK
# Out:
#          Date Region Area (km square) Population (Consensus 2017)  \
# 180  04-04-20    AJK           13,297                   4,045,000
# 187  05-04-20    AJK           13,297                   4,045,000
# 194  06-04-20    AJK           13,297                   4,045,000
# 201  07-04-20    AJK           13,297                   4,045,000
# 208  08-04-20    AJK           13,297                   4,045,000
# 215  09-04-20    AJK           13,297                   4,045,000
# 222  10-04-20    AJK           13,297                   4,045,000
# 229  11-04-20    AJK           13,297                   4,045,000
# 236  12-04-20    AJK           13,297                   4,045,000
# 243  13-04-20    AJK           13,297                   4,045,000
# 250  14-04-20    AJK           13,297                   4,045,000
# 257  15-04-20    AJK           13,297                   4,045,000
# 264  16-04-20    AJK           13,297                   4,045,000
# ...

# %%
#data of Balochistan
regional_data_Balochistan=df3.Region=='Balochistan'
df4_Balochistan=df3[regional_data_Balochistan].copy()
df4_Balochistan
# Out:
#          Date       Region Area (km square) Population (Consensus 2017)  \
# 181  04-04-20  Balochistan          347,190                  12,344,739
# 188  05-04-20  Balochistan          347,190                  12,344,739
# 195  06-04-20  Balochistan          347,190                  12,344,739
# 202  07-04-20  Balochistan          347,190                  12,344,739
# 209  08-04-20  Balochistan          347,190                  12,344,739
# 216  09-04-20  Balochistan          347,190                  12,344,739
# 223  10-04-20  Balochistan          347,190                  12,344,739
# 230  11-04-20  Balochistan          347,190                  12,344,739
# 237  12-04-20  Balochistan          347,190                  12,344,739
# 244  13-04-20  Balochistan          347,190                  12,344,739
# 251  14-04-20  Balochistan          347,190                  12,344,739
# 258  15-04-20  Balochistan          347,190                  12,344,739
# ...

# %%
#data of Sindh
regional_data_Sindh=df3.Region=='Sindh'
df4_Sindh=df3[regional_data_Sindh].copy()
df4_Sindh
# Out:
#          Date Region Area (km square) Population (Consensus 2017)  \
# 186  04-04-20  Sindh          140,914                  47,893,244
# 193  05-04-20  Sindh          140,914                  47,893,244
# 200  06-04-20  Sindh          140,914                  47,893,244
# 207  07-04-20  Sindh          140,914                  47,893,244
# 214  08-04-20  Sindh          140,914                  47,893,244
# 221  09-04-20  Sindh          140,914                  47,893,244
# 228  10-04-20  Sindh          140,914                  47,893,244
# 235  11-04-20  Sindh          140,914                  47,893,244
# 242  12-04-20  Sindh          140,914                  47,893,244
# 249  13-04-20  Sindh          140,914                  47,893,244
# 256  14-04-20  Sindh          140,914                  47,893,244
# 263  15-04-20  Sindh          140,914                  47,893,244
# 270  16-04-20  Sindh          140,914                  47,893,244
# ...

# %%
#data of punjab 
regional_data_Punjab=df3.Region=='Punjab'
df4_Punjab=df3[regional_data_Punjab].copy()
df4_Punjab
# Out:
#          Date  Region Area (km square) Population (Consensus 2017)  \
# 185  04-04-20  Punjab          205,345                 119,017,465
# 192  05-04-20  Punjab          205,345                 119,017,465
# 199  06-04-20  Punjab          205,345                 119,017,465
# 206  07-04-20  Punjab          205,345                 119,017,465
# 213  08-04-20  Punjab          205,345                 119,017,465
# 220  09-04-20  Punjab          205,345                 119,017,465
# 227  10-04-20  Punjab          205,345                 119,017,465
# 234  11-04-20  Punjab          205,345                 119,017,465
# 241  12-04-20  Punjab          205,345                 119,017,465
# 248  13-04-20  Punjab          205,345                 119,017,465
# 255  14-04-20  Punjab          205,345                 119,017,465
# 262  15-04-20  Punjab          205,345                 119,017,465
# 269  16-04-20  Punjab          205,345                 119,017,465
# ...

# %%
#data of KP
regional_data_KP=df3.Region=='KP'
df4_KP=df3[regional_data_KP].copy()
df4_KP
# Out:
#          Date Region Area (km square) Population (Consensus 2017)  \
# 184  04-04-20     KP           74,521                  39,523,371
# 191  05-04-20     KP           74,521                  39,523,371
# 198  06-04-20     KP           74,521                  39,523,371
# 205  07-04-20     KP           74,521                  39,523,371
# 212  08-04-20     KP           74,521                  39,523,371
# 219  09-04-20     KP           74,521                  39,523,371
# 226  10-04-20     KP           74,521                  39,523,371
# 233  11-04-20     KP           74,521                  39,523,371
# 240  12-04-20     KP           74,521                  39,523,371
# 247  13-04-20     KP           74,521                  39,523,371
# 254  14-04-20     KP           74,521                  39,523,371
# 261  15-04-20     KP           74,521                  39,523,371
# 268  16-04-20     KP           74,521                  39,523,371
# ...

# %%
#data of KPTD
regional_data_KPTD=df2.Region=='KPTD'
df4_KPTD=df2[regional_data_KPTD].copy()
df4_KPTD
# Out:
#         Date Region Area (km square) Population (Consensus 2017)  \
# 4   11-03-20   KPTD           27,220                   4,996,556
# 12  12-03-20   KPTD           27,220                   4,996,556
# 20  13-03-20   KPTD           27,220                   4,996,556
# 28  14-03-20   KPTD           27,220                   4,996,556
# 36  15-03-20   KPTD           27,220                   4,996,556
# 44  16-03-20   KPTD           27,220                   4,996,556
# 52  17-03-20   KPTD           27,220                   4,996,556
# 60  18-03-20   KPTD           27,220                   4,996,556
# 68  19-03-20   KPTD           27,220                   4,996,556
# 76  20-03-20   KPTD           27,220                   4,996,556
# 84  21-03-20   KPTD           27,220                   4,996,556
# 92  22-03-20   KPTD           27,220                   4,996,556
#
#     COVID-19 Lockdown (1= no lockdown        2= school closure          3 = Country wide lockdown)  \
# ...

# %%
#data of GB
regional_data_GB=df3.Region=='GB'
df4_GB=df3[regional_data_GB].copy()
df4_GB
# Out:
#          Date Region Area (km square) Population (Consensus 2017)  \
# 182  04-04-20     GB           72,496                   1,900,000
# 189  05-04-20     GB           72,496                   1,900,000
# 196  06-04-20     GB           72,496                   1,900,000
# 203  07-04-20     GB           72,496                   1,900,000
# 210  08-04-20     GB           72,496                   1,900,000
# 217  09-04-20     GB           72,496                   1,900,000
# 224  10-04-20     GB           72,496                   1,900,000
# 231  11-04-20     GB           72,496                   1,900,000
# 238  12-04-20     GB           72,496                   1,900,000
# 245  13-04-20     GB           72,496                   1,900,000
# 252  14-04-20     GB           72,496                   1,900,000
# 259  15-04-20     GB           72,496                   1,900,000
# 266  16-04-20     GB           72,496                   1,900,000
# ...

# %%
#visualizing the test performed
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Cumulative  tests performed'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Cumulative  tests performed'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Cumulative  tests performed'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Cumulative  tests performed'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Cumulative  tests performed'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Cumulative  tests performed'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Cumulative  tests performed'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("TEST PERFORMED")
plt.legend()

# %%
#visualizing the tests positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Cumulative  Test positive'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Cumulative  Test positive'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Cumulative  Test positive'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Cumulative  Test positive'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Cumulative  Test positive'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Cumulative  Test positive'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Cumulative  Test positive'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("TEST POSITIVE")
plt.legend()

# %%
#visualizing 'still admitted'
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Still admitted'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Still admitted'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Still admitted'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Still admitted'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Still admitted'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Still admitted'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Still admitted'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("Still admitted")
plt.legend()

# %%
#visualizing the 'discharged'
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Discharged'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Discharged'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Discharged'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Discharged'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Discharged'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Discharged'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Discharged'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("Discharged")
plt.legend()

# %%
#visualizing the 'expired'
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Cumulative Expired (region/province wise)'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Cumulative Expired (region/province wise)'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Cumulative Expired (region/province wise)'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Cumulative Expired (region/province wise)'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Cumulative Expired (region/province wise)'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Cumulative Expired (region/province wise)'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Cumulative Expired (region/province wise)'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("Cumulative Expired")
plt.legend()

# %%
#visualizing the 'number of hospitals'
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['No of hospitals '],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['No of hospitals '],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['No of hospitals '],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['No of hospitals '],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['No of hospitals '],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['No of hospitals '],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['No of hospitals '],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("No of hospitals ")
plt.legend()

# %%
#Visualizing the 'beds for COVID'
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df4_GB.Date,df4_GB['Beds for COVID'],color='blue',label='GB')
plt.plot(df4_ICT.Date,df4_ICT['Beds for COVID'],color='green',label='ICT')
plt.plot(df4_Sindh.Date,df4_Sindh['Beds for COVID'],color='red',label='Sindh')
plt.plot(df4_Punjab.Date,df4_Punjab['Beds for COVID'],color='orange',label='Punjab')
plt.plot(df4_Balochistan.Date,df4_Balochistan['Beds for COVID'],color='black',label='Balochistan')
plt.plot(df4_AJK.Date,df4_AJK['Beds for COVID'],color='brown',label='AJK')
plt.plot(df4_KP.Date,df4_KP['Beds for COVID'],color='gray',label='KP')
plt.xlabel("DATE")
plt.ylabel("Beds for COVID")
plt.legend()

# %%
#comparing the regions population wise
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(15,10)
plt.scatter(df4_GB.Region,df4_GB['Population (Consensus 2017)'],color='blue',label='GB')
plt.scatter(df4_ICT.Region,df4_ICT['Population (Consensus 2017)'],color='green',label='ICT')
plt.scatter(df4_AJK.Region,df4_AJK['Population (Consensus 2017)'],color='brown',label='AJK')
plt.scatter(df4_Balochistan.Region,df4_Balochistan['Population (Consensus 2017)'],color='black',label='Balochistan')
plt.scatter(df4_KP.Region,df4_KP['Population (Consensus 2017)'],color='gray',label='KP')
plt.scatter(df4_Sindh.Region,df4_Sindh['Population (Consensus 2017)'],color='red',label='Sindh')
plt.scatter(df4_Punjab.Region,df4_Punjab['Population (Consensus 2017)'],color='orange',label='Punjab')
plt.xlabel("Regions")
plt.ylabel("Population (Consensus 2017)")
plt.legend()

# %%
#population to bed ratio
def one_bed_for_how_many_people():
    ICT_one_bed_for_how_many_people=2001579/358
    GB_one_bed_for_how_many_people=1900000/151
    AJK_one_bed_for_how_many_people=4045000/304
    KP_one_bed_for_how_many_people=39523371/4093
    Sindh_one_bed_for_how_many_people=47893244/4688
    Punjab_one_bed_for_how_many_people=119017465/2674
    Balochistan_one_bed_for_how_many_people=12344739/2136
    return ICT_one_bed_for_how_many_people,GB_one_bed_for_how_many_people,AJK_one_bed_for_how_many_people,KP_one_bed_for_how_many_people,Sindh_one_bed_for_how_many_people,Punjab_one_bed_for_how_many_people,Balochistan_one_bed_for_how_many_people
one_bed_for_how_many_people()
# Out:
# (5591.002793296089,
#  12582.781456953642,
#  13305.921052631578,
#  9656.333007573907,
#  10216.135665529011,
#  44509.14921465969,
#  5779.372191011236)

# %%
#quarantine facilities to population ratio
def quarantine_fac_for_how_many_people():
    ICT_quarantine_fac_for_how_many_people=2001579/16
    GB_quarantine_fac_for_how_many_people=1900000/43
    AJK_quarantine_fac_for_how_many_people=4045000/60
    KP_quarantine_fac_for_how_many_people=39523371/279
    Sindh_quarantine_fac_for_how_many_people=47893244/17
    Punjab_quarantine_fac_for_how_many_people=119017465/233
    Balochistan_quarantine_fac_for_how_many_people=12344739/68
    return ICT_quarantine_fac_for_how_many_people,GB_quarantine_fac_for_how_many_people,AJK_quarantine_fac_for_how_many_people,KP_quarantine_fac_for_how_many_people,Sindh_quarantine_fac_for_how_many_people,Punjab_quarantine_fac_for_how_many_people,Balochistan_quarantine_fac_for_how_many_people
quarantine_fac_for_how_many_people()
# Out:
# (125098.6875,
#  44186.04651162791,
#  67416.66666666667,
#  141660.82795698923,
#  2817249.6470588236,
#  510804.5708154506,
#  181540.2794117647)

# %%
#population to hospital ratio
def hospital_population_ratio():
    ICT_hospital_population_ratio=2001579/22
    GB_hospital_population_ratio=1900000/26
    AJK_hospital_population_ratio=4045000/16
    KP_hospital_population_ratio=39523371/200
    Sindh_hospital_population_ratio=47893244/169
    Punjab_hospital_population_ratio=119017465/188
    Balochistan_hospital_population_ratio=12344739/96
    return ICT_hospital_population_ratio,GB_hospital_population_ratio,AJK_hospital_population_ratio,KP_hospital_population_ratio,Sindh_hospital_population_ratio,Punjab_hospital_population_ratio,Balochistan_hospital_population_ratio
hospital_population_ratio()
# Out:
# (90980.86363636363,
#  73076.92307692308,
#  252812.5,
#  197616.855,
#  283391.97633136093,
#  633071.6223404255,
#  128591.03125)

# %%
#Difference of 'cumulative cases' and 'tests performed'
def cases_performed_difference():
    ICT_CPD=8455-8455
    GB_CPD=3591-3273
    AJK_CPD=1588-1588
    KP_CPD=12921-13930
    Sindh_CPD=38181-38181
    Punjab_CPD=42456-71726
    Balochistan_CPD=10404-7212
    return ICT_CPD,GB_CPD,AJK_CPD,KP_CPD,Sindh_CPD,Punjab_CPD,Balochistan_CPD
cases_performed_difference()
# Out:
# (0, 318, 0, -1009, 0, -29270, 3192)

# %%
#Difference of 'tests performed' and 'tests positive'
def performed_positive_difference():
    ICT_PPD=8455-235
    GB_PPD=3273-308
    AJK_PPD=1588-55
    KP_PPD=13930-1793
    Sindh_PPD=38181-4232
    Punjab_PPD=71726-5378
    Balochistan_PPD=7212-722
    return ICT_PPD,GB_PPD,AJK_PPD,KP_PPD,Sindh_PPD,Punjab_PPD,Balochistan_PPD
performed_positive_difference()
# Out:
# (8220, 2965, 1533, 12137, 33949, 66348, 6490)

# %%
#Difference of 'tests positive' and 'total expired'
def positive_expired_difference():
    ICT_PED=235-3
    GB_PED=308-3
    AJK_PED=55-0
    KP_PED=1793-93
    Sindh_PED=4232-78
    Punjab_PED=5378-81
    Balochistan_PED=722-11
    return ICT_PED,GB_PED,AJK_PED,KP_PED,Sindh_PED,Punjab_PED,Balochistan_PED
positive_expired_difference()
# Out:
# (232, 305, 55, 1700, 4154, 5297, 711)

# %%
#Rankings of regions as per above calculations
df5=pd.read_csv("Ranking chart.csv")
df5
# Out:
#    SCORE  RANKS Bed to population ratio  \
# 0      7      1                     ICT
# 1      6      2             Balochistan
# 2      5      3                      KP
# 3      4      4                   Sindh
# 4      3      5                      GB
# 5      2      6                     AJK
# 6      1      7                  Punjab
#
#   Quarantine facilities to population ratio Cases - performed  \
# 0                                        GB            Punjab
# 1                                       AJK                KP
# 2                                       ICT             Sindh
# 3                                        KP               ICT
# 4                               Balochistan               AJK
# 5                                    Punjab                GB
# 6                                     Sindh       Balochistan
#
#   Performed - positive Positive - expired Hospital to population Ratio
# ...

# %%
#Final output
df6=pd.read_csv("Output.csv")
df6
# Out:
#         Region  Total Score  RATING(DESCRIPTION)
# 0           KP           29  1 (MOST SUCCESSFUL)
# 1          ICT           28       2 (SUCCESSFUL)
# 2       Punjab           25          3 (AVERAGE)
# 3           GB           25       4 (STRUGGLING)
# 4        Sindh           24  5 (MOST STRUGGLING)
# 5  Balochistan           20                    6
# 6          AJK           17                    7
