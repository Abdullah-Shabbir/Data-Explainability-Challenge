# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_csv("unique tests.csv")
df1.dropna()
df1
# Out:
#       DATE  ICT_unique_performed  ICT_unique_positive  AJK_unique_performed  \
# 0   05-Apr                 175.0                  2.0                  42.0
# 1   06-Apr                 127.0                  4.0                  14.0
# 2   07-Apr                  50.0                  1.0                  84.0
# 3   08-Apr                 175.0                  9.0                  50.0
# 4   09-Apr                 137.0                 10.0                  47.0
# 5   10-Apr                 142.0                  5.0                  50.0
# 6   11-Apr                 105.0                  6.0                 114.0
# 7   12-Apr                  90.0                  6.0                  68.0
# 8   13-Apr                 266.0                  2.0                  97.0
# 9   14-Apr                 111.0                  0.0                  82.0
# 10  15-Apr                 526.0                  9.0                  37.0
# ...

# %%
df2=df1.dropna()
df2
# Out:
#       DATE  ICT_unique_performed  ICT_unique_positive  AJK_unique_performed  \
# 0   05-Apr                 175.0                  2.0                  42.0
# 1   06-Apr                 127.0                  4.0                  14.0
# 2   07-Apr                  50.0                  1.0                  84.0
# 3   08-Apr                 175.0                  9.0                  50.0
# 4   09-Apr                 137.0                 10.0                  47.0
# 5   10-Apr                 142.0                  5.0                  50.0
# 6   11-Apr                 105.0                  6.0                 114.0
# 7   12-Apr                  90.0                  6.0                  68.0
# 8   13-Apr                 266.0                  2.0                  97.0
# 9   14-Apr                 111.0                  0.0                  82.0
# 10  15-Apr                 526.0                  9.0                  37.0
# ...

# %%
df2_ICT=df2.drop(['AJK_unique_performed','AJK_unique_positive','Sindh_unique_performed','Sindh_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','Punjab_unique_performed','Punjab_unique_positive','KP_unique_performed','KP_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_ICT.head()
# Out:
#      DATE  ICT_unique_performed  ICT_unique_positive
# 0  05-Apr                 175.0                  2.0
# 1  06-Apr                 127.0                  4.0
# 2  07-Apr                  50.0                  1.0
# 3  08-Apr                 175.0                  9.0
# 4  09-Apr                 137.0                 10.0

# %%
df2_AJK=df2.drop(['ICT_unique_performed','ICT_unique_positive','Sindh_unique_performed','Sindh_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','Punjab_unique_performed','Punjab_unique_positive','KP_unique_performed','KP_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_AJK.head()
# Out:
#      DATE  AJK_unique_performed  AJK_unique_positive
# 0  05-Apr                  42.0                  1.0
# 1  06-Apr                  14.0                  3.0
# 2  07-Apr                  84.0                  3.0
# 3  08-Apr                  50.0                  1.0
# 4  09-Apr                  47.0                  9.0

# %%
df2_Sindh=df2.drop(['AJK_unique_performed','AJK_unique_positive','ICT_unique_performed','ICT_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','Punjab_unique_performed','Punjab_unique_positive','KP_unique_performed','KP_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_Sindh.head()
# Out:
#      DATE  Sindh_unique_performed  Sindh_unique_positive
# 0  05-Apr                    25.0                   25.0
# 1  06-Apr                   285.0                   17.0
# 2  07-Apr                   458.0                   51.0
# 3  08-Apr                   634.0                   54.0
# 4  09-Apr                   758.0                   50.0

# %%
df2_Balochistan=df2.drop(['AJK_unique_performed','AJK_unique_positive','Sindh_unique_performed','Sindh_unique_positive','ICT_unique_performed','ICT_unique_positive','Punjab_unique_performed','Punjab_unique_positive','KP_unique_performed','KP_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_Balochistan.head()
# Out:
#      DATE  Balochistan_unique_performed  Balochistan_unique_positive
# 0  05-Apr                         112.0                         10.0
# 1  06-Apr                         264.0                          6.0
# 2  07-Apr                         221.0                         11.0
# 3  08-Apr                          93.0                          4.0
# 4  09-Apr                         125.0                          6.0

# %%
df2_Punjab=df2.drop(['AJK_unique_performed','AJK_unique_positive','Sindh_unique_performed','Sindh_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','ICT_unique_performed','ICT_unique_positive','KP_unique_performed','KP_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_Punjab.head()
# Out:
#      DATE  Punjab_unique_performed  Punjab_unique_positive
# 0  05-Apr                   1145.0                    91.0
# 1  06-Apr                     71.0                   330.0
# 2  07-Apr                   2349.0                   425.0
# 3  08-Apr                   1213.0                   112.0
# 4  09-Apr                   1254.0                   141.0

# %%
df2_KP=df2.drop(['AJK_unique_performed','AJK_unique_positive','Sindh_unique_performed','Sindh_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','Punjab_unique_performed','Punjab_unique_positive','ICT_unique_performed','ICT_unique_positive','GB_unique_performed','GB_unique_positive'],axis='columns')
df2_KP.head()
# Out:
#      DATE  KP_unique_performed  KP_unique_positive
# 0  05-Apr                145.0                29.0
# 1  06-Apr                205.0                33.0
# 2  07-Apr                129.0                95.0
# 3  08-Apr                159.0                27.0
# 4  09-Apr                400.0                33.0

# %%
df2_GB=df2.drop(['AJK_unique_performed','AJK_unique_positive','Sindh_unique_performed','Sindh_unique_positive','Balochistan_unique_performed','Balochistan_unique_positive','Punjab_unique_performed','Punjab_unique_positive','KP_unique_performed','KP_unique_positive','ICT_unique_performed','ICT_unique_positive'],axis='columns')
df2_GB.head()
# Out:
#      DATE  GB_unique_performed  GB_unique_positive
# 0  05-Apr                115.0                13.0
# 1  06-Apr                 23.0                 4.0
# 2  07-Apr                 17.0                 1.0
# 3  08-Apr                112.0                 1.0
# 4  09-Apr                 16.0                 1.0

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_ICT.DATE,df2_ICT['ICT_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_ICT.DATE,df2_ICT['ICT_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("ICT")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_GB.DATE,df2_GB['GB_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_GB.DATE,df2_GB['GB_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("GB")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_AJK.DATE,df2_AJK['AJK_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_AJK.DATE,df2_AJK['AJK_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("AJK")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_Sindh.DATE,df2_Sindh['Sindh_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_Sindh.DATE,df2_Sindh['Sindh_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("Sindh")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_Punjab.DATE,df2_Punjab['Punjab_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_Punjab.DATE,df2_Punjab['Punjab_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("Punjab")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_Balochistan.DATE,df2_Balochistan['Balochistan_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_Balochistan.DATE,df2_Balochistan['Balochistan_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("Balochistan")
plt.legend()

# %%
#comparing the test performed and test positive
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

matplotlib.rcParams['figure.figsize']=(15,10)
plt.plot(df2_KP.DATE,df2_KP['KP_unique_positive'],color='blue',label='Positive tests')
plt.plot(df2_KP.DATE,df2_KP['KP_unique_performed'],color='green',label='performed test')

plt.xlabel("DATE")
plt.ylabel("KP")
plt.legend()
